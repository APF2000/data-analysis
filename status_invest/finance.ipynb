# %%
# !pip install yfinance
# !pip install investpy
# https://pypi.org/project/yfinance/
# https://pypi.org/project/investpy/

# %%
import yfinance as yf
import investpy as inv
import pandas as pd

# %%
inv.stocks.get_stocks(country='brazil')
# Out:
#     country                name                               full_name  \
# 0    brazil       ABC BRASIL PN                     Banco ABC Brasil SA
# 1    brazil       BRASILAGRO ON                   BrasilAgro - Co ON NM
# 2    brazil          RUMO ON NM  RUMO Logistica Operadora Multimodal SA
# 3    brazil       ALPARGATAS ON                           Alpargatas SA
# 4    brazil       ALPARGATAS PN                           Alpargatas SA
# ..      ...                 ...                                     ...
# 744  brazil  Integral Brei Reit     Fdo Inv Imob Fof Integral Brei Reit
# 745  brazil             Vbi Cri                  Fi Imobiliario Vbi Cri
# 746  brazil        Hedge Realty      Hedge Realty Devl Fdo Inv Imob Etf
# 747  brazil              Rb Cap      Rb Cap Desenvolvimento Res Iii Fii
# 748  brazil            Treecorp          Treecorp Real Estate Fii I Etf
#
#              isin currency  symbol
# 0    BRABCBACNPR4      BRL   ABCB4
# 1    BRAGROACNOR7      BRL   AGRO3
# 2    BRRAILACNOR9      BRL   RAIL3
# 3    BRALPAACNOR0      BRL   ALPA3
# 4    BRALPAACNPR7      BRL   ALPA4
# ..            ...      ...     ...
# 744  BRIBFFCTF007      BRL  IBFF11
# 745  BRCVBICTF001      BRL  CVBI11
# 746  BRHRDFCTF000      BRL  HRDF11
# 747  BRRSPDCTF006      BRL  RSPD11
# 748  BRTCPFCTF001      BRL  TCPF11
#
# [749 rows x 6 columns]

# %%
inv.get_stock_historical_data(stock='BPAC11',
                                        country='brazil',
                                        from_date='01/01/2020',
                                        to_date='01/01/2022')
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 inv.get_stock_historical_data(stock='BPAC11',
#       2                                         country='brazil',
#       3                                         from_date='01/01/2020',
#       4                                         to_date='01/01/2022')
#
# File ~/Documents/Poli/5oQuadriAula/TCC/data-analysis/.venv/lib/python3.12/site-packages/investpy/stocks.py:664, in get_stock_historical_data(stock, country, from_date, to_date, as_json, order, interval)
#     661 req = requests.post(url, headers=head, data=params)
#     663 if req.status_code != 200:
# --> 664     raise ConnectionError(
#     665         "ERR#0015: error " + str(req.status_code) + ", try again later."
#     666     )
#     668 if not req.text:
#     669     continue
#
# ConnectionError: ERR#0015: error 403, try again later.

# %%
inv.search_quotes(text='apple', products=['stocks'],
        countries=['united states'], n_results=1)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 inv.search_quotes(text='apple', products=['stocks'],
#       2         countries=['united states'], n_results=1)
#
# File ~/Documents/Poli/5oQuadriAula/TCC/data-analysis/.venv/lib/python3.12/site-packages/investpy/search.py:160, in search_quotes(text, products, countries, n_results)
#     157 req = requests.post(url, headers=headers, data=params)
#     159 if req.status_code != 200:
# --> 160     raise ConnectionError(
#     161         f"ERR#0015: error {req.status_code}, try again later."
#     162     )
#     164 data = req.json()
#     166 if data["total"]["quotes"] == 0:
#
# ConnectionError: ERR#0015: error 403, try again later.

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# get all stock info
msft.info

# get historical market data
hist = msft.history(period="1mo")

# show meta information about the history (requires history() to be called first)
msft.history_metadata

# show actions (dividends, splits, capital gains)
msft.actions
msft.dividends
msft.splits
msft.capital_gains  # only for mutual funds & etfs

# show share count
msft.get_shares_full(start="2022-01-01", end=None)

# show financials:
# - income statement
msft.income_stmt
msft.quarterly_income_stmt
# - balance sheet
msft.balance_sheet
msft.quarterly_balance_sheet
# - cash flow statement
msft.cashflow
msft.quarterly_cashflow
# see `Ticker.get_income_stmt()` for more options

# show holders
msft.major_holders
msft.institutional_holders
msft.mutualfund_holders
msft.insider_transactions
msft.insider_purchases
msft.insider_roster_holders

# show recommendations
msft.recommendations
msft.recommendations_summary
msft.upgrades_downgrades

# Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default. 
# Note: If more are needed use msft.get_earnings_dates(limit=XX) with increased limit argument.
msft.earnings_dates

# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# show options expirations
msft.options

# show news
msft.news

# get option chain for specific expiration
opt = msft.option_chain('YYYY-MM-DD')
# data available via: opt.calls, opt.puts
