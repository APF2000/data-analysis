# %%
# %load_ext autoreload
# %autoreload 2

# %%
from stock_data_fetcher import StockDataFetcher
from stock_data_analyser import StockDataAnalyser
from stock_data_plotter import StockDataPlotter

# %%
fetcher = StockDataFetcher()
stock_data = fetcher.fetch_stock_data()
stock_data
# Out:
#      ticker    param_name  year    value
# 0     bbse3            dy  2024   7.1124
# 1     bbse3            dy  2023  10.3602
# 2     bbse3            dy  2022   5.8324
# 3     bbse3            dy  2021   4.8048
# 4     bbse3            dy  2020   9.4030
# ...     ...           ...   ...      ...
# 1375  cple6  lucros_cagr5  2012      NaN
# 1376  cple6  lucros_cagr5  2011      NaN
# 1377  cple6  lucros_cagr5  2010      NaN
# 1378  cple6  lucros_cagr5  2009      NaN
# 1379  cple6  lucros_cagr5  2008      NaN
#
# [1380 rows x 4 columns]

# %%
analyser = StockDataAnalyser(stock_data)
analyser.analyse()
# Out:
#      ticker    param_name  year    value
# 0     bbse3            dy  2024   7.1124
# 1     bbse3            dy  2023  10.3602
# 2     bbse3            dy  2022   5.8324
# 3     bbse3            dy  2021   4.8048
# 4     bbse3            dy  2020   9.4030
# ...     ...           ...   ...      ...
# 1375  cple6  lucros_cagr5  2012      NaN
# 1376  cple6  lucros_cagr5  2011      NaN
# 1377  cple6  lucros_cagr5  2010      NaN
# 1378  cple6  lucros_cagr5  2009      NaN
# 1379  cple6  lucros_cagr5  2008      NaN
#
# [1380 rows x 4 columns]

# %%
plotter = StockDataPlotter(stock_data)
plotter.plot()
